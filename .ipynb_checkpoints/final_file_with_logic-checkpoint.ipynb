# %%
# !pip install reportlab

# %%
import csv #library
from reportlab.lib.pagesizes import letter
from reportlab.lib.colors import pink
from reportlab.lib.colors import Color
from reportlab.lib.colors import black
from reportlab.pdfgen import canvas
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import csv #library
# ----> 2 from reportlab.lib.pagesizes import letter
#       3 from reportlab.lib.colors import pink
#       4 from reportlab.lib.colors import Color
#
# ModuleNotFoundError: No module named 'reportlab'

# %%
def generate_child_health_report(input_filename, output_filename):   
    # Labels for the report
    heading_text = "Child Health Status Report"
    survey_text = "School Based Health Assessment survey"
    academy_text = ""
    grade_class_text = "Grade/class: "
    child_name_text = "Child Name: "
    age_text = "Age: "
    vaccine_status_text = "Vaccine Status: "
    gender_text = "Gender: "
    roll_no_text = "Roll No: "
    recordid = "Record ID"
    date = "Date "
    
    
    #medical history Section 2
    past_medical = "Past Medical History"
    worms_infestation_text = "Worms Infestation: "
    mumps_text ="Mumps: "
    upper_respiratory_tract_infection_text ="Upper respiratory tract infection: "
    chicken_pox_text ="Chicken Pox: "
    asthma_or_reactive_airway_disease_text ="Asthma OR Reactive airway disease: "
    
    #General Physical Examination Section 3
    general_physical_examination = "General Physical Examination"
    weight_text = "Weight kg "
    height_text = "Height cm "
    muac_range_text = "MUAC "
    pulse_text = "Pulse "
    blood_pressure = "BP(Sy/Di) "
    respiratory_rate_text = "Respiratory rate "
    o2_saturation_text = "o2 saturation "
    temperature_text = "Temp "
    eye_visiontestingchart = "Eye Vision Testing Chart "
    b_observation_of_snellen_chart_evtc = "B Observation of Snellen Chart / Eye Vision Testing Chart "
    anemia_text = "Anemia "
    
    #Systemic Examination section 4
    systemic_examination_text = "Systemic Examination: "
    
    respiratory_examination_text = "Respiratory Examination: "
    
    childs_respiratory_examination_6_2 = " - Child's respiratory examination - "
    ap_diameter_shape_6_2_a = " - AP diameter / shape - "
    chest_wall_for_lumps_bumps_6_1_b  =" - Chest wall for lumps/bumps - "
    tenderness_6_2_b =" - Tenderness - "
    chest_wall_expansion_6_3_b = " - Chest wall expansion - "
    breath_sounds_6_1_d = " - Breath sounds - "
    added_sounds_6_3_d = " - Added sounds - "
    
    #Cardiovascular Examination
    
    cardiovascular_examination_text = "Cardiovascular Examination"
    cardiovascular_examination_6_2 = " - 6.2 Cardiovascular Examination  -  "
    precordial_bulge_6_2_e = " - 6.2(e)Precordial bulge  -  "
    pectus_carinatum_excavatum_6_3_e = " - 6.3(e)Pectus carinatum / excavatum  -  "
    scars_6_4_e = " - 6.4(e)Scars  -  "
    visible_cardiac_impulse_6_5_e = " - 6.5(e)Visible cardiac impulse  -  "
    increased_WOB_tachypnea_6_6_e = " - 6.6(e)Increased WOB-tachypnea, intercostals indrawing, tracheal tug, head bobbing, nasal flaring  -   "
    peripheral_pulses_felt = " - 6.1(f)Peripheral pulses felt (Radial, brachial rate, rhythm, volume, contour)  -  "
    apex_position_6_1_g = " - 6.1(g)Apex: Position  -  "
    if_apex_abnormal_specify_6_1_g = " - 6.1(g)if Apex, Abnormal specify  -  "
    Murmurs_6_3_h = " - 6.3 (h)Murmurs  -  "
    if_yes_specify_6_4_h = " - 6.4 (h) If yes, specify  -  "
    
    
    #Teeth Problem
    teeth_problem_text = "Teeth Problem"
    brush_your_teeth = "Brush your Teeth "
    clean_teeth = "Method to clean teeth "
    regular_dentist = "Regular dentist "
    dental_professional = "Dental professional "
    ever_dentist = "Ever been to the dentist"
    oral_hygiene = " Bad oral hygiene "
    present_Examination = "Present on Examination "
    toothach = "Toothach "
    sensitivity= "sensitivity "
    pain_jaw_joints = "Pain in jaw joints "
    bleeding_gums ="Bleeding gums while brushin "
    dry_mouth = "Persistent dry mouth "
    bad_breath = "Bad breath "
    white_patch = "White patch on your tongue "
    hole_teeth = "Hole in teeth (decay) "
    ulcers = "Ulcers "
    bleeding_gums = "bleeding gums "
    loosening_teeth = "Loosening of teeth "
    swelling_neck = "Swelling around the neck "
    mouth_pain_night = "Severe mouth pain at night "
    tooth_pain_night = "Severe tooth pain at night "
    pain_in_jaws = "Pain in jaw(s) "
    not_happy_teeth = "not happy with my teeth "
    dental_caries = "Dental Caries(decay) "
    aphthous_ulcers_stains_plaque = "Aphthous Ulcers/Stains/Plaque "
    other_7_7 = "Other "
    other_7_7_2 = " Other"
    pain = "Pain "
    bleeding_gums = "Bleeding gums "
    loosening_teeth = "Loosening of teeth "
    pain_at_night = "Pain at night "
    stains_plaque = "Stains/ Plaque "
    normal_teeth = "Teeth Problem "
    

    
    
    #Abdominal Examination
    abdominal_examination = "Abdominal Examination"
    abdominal_examination_7 = "7.1 Abdominal Examination  "
    Scars_7_2 = "7.2 Scars"
    Skin_abnormalities = "7.3 Skin abnormalities  "
    Protrusions ="7.4 Protrusions  " 
    tenderness_7 ="7.1Tenderness  " 
    Guarding = "7.2 Guarding  "
    Hepatomegaly = "7.3 Hepatomegaly  "
    Splenomegaly = "7.4 Splenomegaly  "
    Enlarged_kidneys = "7.5Enlarged kidneys "
    Ascites = "7.2(d) Ascites  "
    Bowel_Sounds = "7.1(e) Bowel Sounds  " 

    
    #Neurological Examination
    neurological_examination = "Neurological Examination"
    
    #Gait Examination
    
    gait_examination = "Gait Examination"
    Gait = "Gait "
    Antalgic_gait = "Antalgic gait "
    Circumduction_gait = "Circumduction gait "
    Spastic_gait = "Spastic gait "
    Ataxic_gait = "Ataxic gait "
    Trendelenburg = "Trendelenburg's gait "
    Toe_walking = "Toe-walking gait with absent heel contact "
    Stepping_gait = "Stepping gait "
    Clumsy_gait = "Clumsy gait "
    Central_nervous = "Central nervous system Examination "
    Hypertrophy = "Hypertrophy "
    Seizure_activity = "Seizure activity "
    Wasting = "Wasting "
    Chorea = "Chorea "
    Fasciculation = "Fasciculation "
    Tremor = "Tremor "
    Athetosis = "Athetosis "
    Dystonia = "Dystonia "
    Others = "Others "
    Muscular_Power = "Muscular Power "
    Muscle_tone = "Muscle tone "
    Deep_Tendons = "Deep Tendons Reflexes "
    
    
    
    #Physician Section  section 5
    physician_section_text = "Physician Section: "
    referred_to_pediatric_clinic_text = ""
    referred_to_pediatric_clinic = "Referred to Pediatric Clinic?"
    diagnosis_text = "Diagnosis"
    diagnosis = ""
    doctors_name_speciality = "Name of Doctors and Speciality?"
    test_required = "Test required?"
    medicine_prescribe = "Medicine Prescribe"
    
    
    #3.1 Child vaccinated
    child_vaccinated_text = "Child Vaccinated"
    child_vaccinated = "Child vaccinated?"
    aBCG = "BCG"
    bOPV = "OPV"
    cPenta = "Penta"
    dPCV = "PCV"
    eMeasles = "Measles"
    fChicken_Pox = "Chicken Pox"
    gTyphoid = "Typhoid"
    hCOVID = "COVID-19"
    iothers = "If any others mention name"
    
    #section  11
    life_style ="Life Style"
    food = "Food"
    diet = "Diet"
    sport = "Sprort"
    at_school = "At School"
    out_school = "Outside School"
    tv = "Entertainment"
    s_media = "Social Media"
    s_night = "Sleep at night"
    s_well = "Sleep Well"
    grow_up = "What do you want to be"
    
    
    
    #pageno
    page_1 = "Page 1"
    page_2 = "Page 2"
    


    # Open the CSV file for reading
    with open(input_filename, 'r', newline='') as csvfile:
        reader = csv.DictReader(csvfile)

        # Create a canvas with specified filename and page size (letter)
        c = canvas.Canvas(output_filename, pagesize=letter)
        pink_rgb = (255, 128, 128)

        # Set font properties
        c.setFont("Helvetica", 10)

        # Set initial y-coordinate for text positioning
        y = 750
        # Draw centered heading
        c.setFont("Helvetica-Bold", 12)
        text_width = c.stringWidth(heading_text, "Helvetica-Bold")
        x = (letter[0] - text_width) / 2  # Center the heading horizontally
        c.drawString(x, y, heading_text)
        y -= 30  # Move down for the next line

        # Draw survey text
        c.setFont("Helvetica", 12)
        text_width = c.stringWidth(survey_text, "Helvetica")
        x = (letter[0] - text_width) / 2  # Center the survey text horizontally
        c.drawString(x, y, survey_text)
        y -= 30  # Move down for the next line

        # Iterate over each record in the CSV file
        for row in reader:
            if heading_text == "Child Health Status Report":# Check if a new report begins
                c.showPage()  # Start a new page
                y = 750  # Reset y-coordinate for new page
                # Redraw heading and survey text on the new page
                c.setFont("Helvetica-Bold", 12)
                text_width = c.stringWidth(heading_text, "Helvetica-Bold")
                x = (letter[0] - text_width) / 2
                c.drawString(x, y, heading_text)
                y -= 30  # Move down for the next line
                c.setFont("Helvetica", 12)
                text_width = c.stringWidth(survey_text, "Helvetica")
                x = (letter[0] - text_width) / 2
                c.drawString(x, y, survey_text)
                y -= 30  # Move down for the next line


            # Draw academy information with background color and border 
            c.setFillColorRGB(pink_rgb[0]/255, pink_rgb[1]/255, pink_rgb[2]/255)  # Set fill color to pink using RGB values
            c.setStrokeColor(black)  # Set stroke color to pink
            c.rect(49, y, 555, 21, fill=1)  # Draw a filled rectangle as background
            c.setFont("Helvetica-Bold", 8)
            c.setFillColor("black")  # Set text color to black 
            c.drawString(50, y+5, academy_text + row['1.1School Name?'])
            y += 20
           

            # Draw grade/class information
            c.setFillColor("black")  # Set text color back to black
            y -= 30  # Move down for the next line
            c.setFont("Helvetica", 9)
            c.drawString(50, y, grade_class_text + row['1.2In what grade/class/ standard are you?'])
            c.setFont("Helvetica", 9)
            c.drawString(350, y, age_text + row["1.6Child's Age"])
            c.drawString(430, y, date + row["Date"])
            y -= 20  # Move down for the next line

            # Draw child information
            c.drawString(50, y, child_name_text + row['1.3Child Name'])
            c.drawString(350, y, roll_no_text + row['1.3aChild ID'])
            c.drawString(430, y, recordid + row['Record ID'])
            y -= 20  # Move down for the next line

            # Draw vaccine status and gender
            c.drawString(50, y, vaccine_status_text + row['3.1Child vaccinated?'])
            c.drawString(350, y, gender_text + row["1.7Child's sex"])
            y += 12  # Move down for the next line
#             c.drawString(350, y, roll_no_text + row['1.3aChild ID'])
            y -= 38  # Move down for the next record
            
            
            
            
#             # Draw past medical history
#             c.setFillColor(pink)  # Set fill color to pink
            c.setFillColorRGB(pink_rgb[0]/255, pink_rgb[1]/255, pink_rgb[2]/255)  # Set fill color to pink using RGB values
            c.setStrokeColor(black)  # Set stroke color to pink
            c.rect(49, y, 555, 21, fill=1)  # Draw a filled rectangle as background
            c.setFont("Helvetica-Bold", 10)
            c.setFillColor("black")  # Set text color to black 
            c.drawString(50, y+5, past_medical)
            y += 20

            
#             # Draw past medical history details
            c.setFillColor("black")  # Set text color back to black
            y -= 30  # Move down for the next line
            c.setFont("Helvetica", 9)
            c.drawString(50, y, worms_infestation_text + row['4.1Worms infestation'])
            c.drawString(190, y, mumps_text + row['4.4Mumps'])
            c.drawString(260, y, upper_respiratory_tract_infection_text + row['4.5Upper respiratory tract infection'])
            c.drawString(470, y, chicken_pox_text + row['4.8Chicken Pox'])
            #horizontal line
            y-=5
            c.line(50, y, 50 + 555, y)
            y -= 17
            c.drawString(50, y, asthma_or_reactive_airway_disease_text + row['4.10Asthma OR Reactive airway disease'])
            y-=1
            y -= 25  # Move down for the next line
            
            
#             # Draw general physical examination heading
#             c.setFillColor(pink)  # Set fill color to pink
            c.setFillColorRGB(pink_rgb[0]/255, pink_rgb[1]/255, pink_rgb[2]/255)  # Set fill color to pink using RGB values
            c.setStrokeColor(black)  # Set stroke color to pink
            c.rect(49, y, 555, 21, fill=1)  # Draw a filled rectangle as background
            c.setFont("Helvetica-Bold", 10)
            c.setFillColor("black")  # Set text color to black 
            c.drawString(50, y+5, general_physical_examination)
            y += 20

#             # Draw general physical examination details
            c.setFillColor("black")  # Set text color back to black
            y -= 30  # Move down for the next line
            c.setFont("Helvetica", 9)
            c.drawString(50, y, weight_text + row['5.2Weight'])
            c.drawString(140, y, height_text + row['5.3Height - range (50-170)'])
            c.drawString(240, y, muac_range_text + row['5.4MUAC - range (5-18.5)'])
            c.drawString(300, y, pulse_text + row['5.5Pulse'])
            c.drawString(370, y, blood_pressure + row['BP(Sy/Di)'])
            c.drawString(470, y, temperature_text + row['5.8Temperature'])
            
            #horizontal line
            y-=5
            c.line(50, y, 50 + 555, y)
            y -= 17  # Move down for the next line
            c.drawString(50, y, respiratory_rate_text + row['5.6Respiratory rate'])
            c.drawString(170, y, o2_saturation_text + row['5.7O2 saturation'])
            c.drawString(280, y, eye_visiontestingchart + row['Eye Vision Testing Chart'])
            c.drawString(470, y, anemia_text + row['5.10Anemia'])
            
            y -= 17  # Move down for the next line   
            y -= 12
            
            
            #Systemic Examination heading
#             c.setFillColor(pink)  # Set fill color to pink
            c.setFillColorRGB(pink_rgb[0]/255, pink_rgb[1]/255, pink_rgb[2]/255)  # Set fill color to pink using RGB values
            c.setStrokeColor(black)  # Set stroke color to pink
            c.rect(49, y, 555, 21, fill=1)  # Draw a filled rectangle as background
            c.setFont("Helvetica-Bold", 11)
            c.setFillColor("black")  # Set text color to black 
            c.drawString(50, y+5, systemic_examination_text)
            y += 20
            
            
            
            
            #Systemic Examination details  
            #Respiratory Examination
            
            c.setFillColor("black")  # Set text color back to black
            y -= 30  # Move down for the next line
            c.setFont("Helvetica-Bold", 10)
            c.drawString(50, y, respiratory_examination_text)  #sub heading Respiratory Examination
            
            child_respiratory_exam = row["6.2Child's respiratory examination"].strip()

            if child_respiratory_exam == "Normal":
                
                # If Child's respiratory examination is "yes", skip drawing other sections
                c.setFont("Helvetica", 9)
                c.drawString(200, y, childs_respiratory_examination_6_2 + " Normal")
            else:
                # Draw Child's respiratory examination
                c.setFont("Helvetica", 9)
                c.drawString(200, y, childs_respiratory_examination_6_2 +" "+ row["6.2Child's respiratory examination"])
                c.drawString(450, y, tenderness_6_2_b + " "+ row['6.2(b)Tenderness'])
            #horizontal line
                y-=5
                c.line(50, y, 50 + 555, y)
                y -= 17  # Move down for the next line
                c.drawString(50, y, chest_wall_for_lumps_bumps_6_1_b + " "+ row['6.1(b)Chest wall for lumps/bumps'])
                c.drawString(220, y, ap_diameter_shape_6_2_a + row['6.2(a)AP diameter / shape'])
            #horizontal line
            
                y-=5
                c.line(50, y, 50 + 555, y)
                y -= 17  # Move down for the next line
                c.drawString(50, y, chest_wall_expansion_6_3_b + row['6.3(b)Chest wall expansion'])
                c.drawString(240, y, breath_sounds_6_1_d + row['6.1(d)Breath sounds'])
                c.drawString(405, y, added_sounds_6_3_d + row['6.3(d)Added sounds'])
                #horizontal line
                y-=5
                c.line(50, y, 50 + 500, y)
                y -= 17  # Move down for the next line
#                 y -= 0 # gap for next section

#for check


#                 y-=5
#                 c.line(50, y, 50 + 500, y)
#                 y -= 17 
                
        
        
        
        
        
        
        
        
        
            
#            
                
             #Cardiovascular Examination
            #horizontal line 
            
            
            
            
            
#           #Cardiovascular Examination
            #horizontal line  
            y-=5
            c.line(50, y, 50 + 555, y)
            y -= 17  
#             c.setFillColor("black")  # Set text color back to black
            c.setFont("Helvetica-Bold", 10)
            c.drawString(50, y, cardiovascular_examination_text)  #sub heading Cardiovascular Examination
        
            cardiovascular_examination_6_2 = row["6.2Cardiovascular Examination"].strip()
            
            if cardiovascular_examination_6_2 == "Normal":
                c.setFont("Helvetica", 9)
                c.drawString(200, y, cardiovascular_examination_6_2)
            else:
                c.setFont("Helvetica", 9)
                c.drawString(200, y, "" + row["6.2Cardiovascular Examination"])
                c.drawString(450, y, precordial_bulge_6_2_e + " "+ row['6.2(e)Precordial bulge'])
            
                c.setFont("Helvetica", 9)
#                 c.drawString(195, y, cardiovascular_examination_6_2 + row["6.2Cardiovascular Examination"])
#             c.drawString(410, y, precordial_bulge_6_2_e + row['6.2(e)Precordial bulge'])
            #horizontal line
                y-=5
                c.line(50, y, 50 + 555, y)
                y -= 17  # Move down for the next line
                c.drawString(50, y, pectus_carinatum_excavatum_6_3_e +" "+ row['6.3(e)Pectus carinatum / excavatum'])
                c.drawString(250, y, scars_6_4_e  +" "+ row['6.4(e)Scars'])
                c.drawString(350, y, visible_cardiac_impulse_6_5_e + " " + row['6.5(e)Visible cardiac impulse'])
            #horizontal line
                y-=5
                c.line(50, y, 50 + 555, y)
                y -= 17  # Move down for the next line
                c.drawString(50, y, increased_WOB_tachypnea_6_6_e +" " + row['6.6(e)Increased WOB-tachypnea, intercostals indrawing, tracheal tug, head bobbing, nasal flaring'])
        
            #horizontal line
                y-=5
                c.line(50, y, 50 + 555, y)
                y -= 17  # Move down for the next line
                c.drawString(50, y, peripheral_pulses_felt  +" "+ row['6.1(f)Peripheral pulses felt (Radial, brachial rate, rhythm, volume, contour)'])
                c.drawString(400, y, apex_position_6_1_g + row['6.1(g)Apex: Position'])
                y-=5
                c.line(50, y, 50 + 555, y)
                y -= 17
                c.drawString(50, y, if_apex_abnormal_specify_6_1_g +" "+ row['6.1(g)if Apex, Abnormal specify'])
                c.drawString(270, y, Murmurs_6_3_h +" "+ row['6.3(h)Murmurs'])
                c.drawString(400, y, if_yes_specify_6_4_h +" " + row['6.4(h)If yes, specify'])
            #horizontal line
                y-=5
                c.line(50, y, 50 + 555, y)
                y -= 17
                
                
                
                #new addd
               
             
            
            
            
            
            ###################################################################
            #########################################################
            ##########################
            
            
            
            
            #option
            
            #Teeth Problem
            y-=5
            c.line(50, y, 50 + 555, y)
            y -= 17  
            c.setFillColor("black")  # Set text color back to black
            c.setFont("Helvetica-Bold", 10)
            c.drawString(50, y, teeth_problem_text)  #sub heading 
            c.setFont("Helvetica", 9) 
            
            normal_teeth = row ["7.7Do you presently experience one or more of the following conditions?  (choice=Normal Teeth)"].strip()
            if normal_teeth =="Normal":
                c.setFont("Helvetica", 9)
                c.drawString(200, y, normal_teeth)
                y-=5 
                c.line(50, y, 50 + 555, y)
                y -= 17
                
            else:
                c.drawString(140, y, normal_teeth)
                c.drawString(290, y, pain + " "+row['7.7Do you presently experience one or more of the following conditions?  (choice=Pain)'])
                c.drawString(430, y, bleeding_gums +" " + row['7.7Do you presently experience one or more of the following conditions?  (choice=Bleeding gums)'])
           
            #horizontal line
                y-=5
                c.line(50, y, 50 + 555, y)
#             y -= 10  # Move down for the next line
            #horizontal line
             
#             y-=5
#             c.line(50, y, 50 + 500, y)
                y -= 17  # Move down for the next line
                c.drawString(50, y, loosening_teeth +" "+ row['7.7Do you presently experience one or more of the following conditions?  (choice=Loosening of teeth)'])
                c.drawString(290, y, pain_at_night +" "+ row['7.7Do you presently experience one or more of the following conditions?  (choice=Severe tooth pain at night)'])
                c.drawString(430, y, stains_plaque  +" "+ row['7.7Do you presently experience one or more of the following conditions?  (choice=Stains/ Plaque)'])
                y-=5
                c.line(50, y, 50 + 555, y)
                y -= 17
            
# #             #horizontal line
#             y-=5
#             c.line(50, y, 50 + 500, y)
#             y -= 17  # Move down for the next line
#             c.drawString(50, y, loosening_teeth  + row['7.7Do you presently experience one or more of the following conditions? Or Is present onExamination(choice=Loosening of teeth)'])
#             c.drawString(210, y, swelling_neck  + row['7.7Do you presently experience one or more of the following conditions? Or Is present onExamination(choice=Swelling around the neck)'])
#             c.drawString(390, y, mouth_pain_night  + row['7.7Do you presently experience one or more of the following conditions? Or Is present onExamination(choice=Severe mouth pain at night)'])
#             y-=5
#             c.line(50, y, 50 + 500, y)
#             y -= 17
#             c.drawString(50, y, tooth_pain_night + row['7.7Do you presently experience one or more of the following conditions? Or Is present onExamination(choice=Severe tooth pain at night)'])
#             c.drawString(220, y, pain_in_jaws + row['7.7Do you presently experience one or more of the following conditions? Or Is present onExamination(choice=I have pains in my jaw(s))'])
#             c.drawString(390, y, not_happy_teeth + row['7.7Do you presently experience one or more of the following conditions? Or Is present onExamination(choice=I am not happy with the appearance of my teeth)'])
#             #horizontal line
#             y-=5
#             c.line(50, y, 50 + 500, y)
#             y -= 17  # Move down for the next line
#             c.drawString(50, y,dental_caries + row['7.7Do you presently experience one or more of the following conditions? Or Is present onExamination(choice=Dental Caries(decay))'])
#             c.drawString(200, y, aphthous_ulcers_stains_plaque + row['7.7Do you presently experience one or more of the following conditions? Or Is present onExamination(choice=Aphthous Ulcers/Stains/Plaque)'])
#             c.drawString(370, y,other_7_7 + row['7.7Do you presently experience one or more of the following conditions? Or Is present onExamination(choice=Other)'])
#             c.drawString(480, y, other_7_7_2 + row['7.7Other'])
#             y-=5 
#             c.line(50, y, 50 + 500, y)
#             y -= 17
            
        
            
#             y-=5 
#             c.line(50, y, 50 + 500, y)
#             y -= 17


# #       #new add
               





            #Abdominal Examination
            y-=5
            c.line(50, y, 50 + 555, y)
            y -= 17

            c.setFillColor("black")  # Set text color back to black
            c.setFont("Helvetica-Bold", 10)
            c.drawString(50, y, abdominal_examination)  #sub heading 
            
            c.setFont("Helvetica", 9)
            abdominal_examination_7 = row ["7.1Abdominal Examination"].strip()
            if abdominal_examination_7 == "Normal":
                c.setFont("Helvetica", 9)
                c.drawString(200, y, abdominal_examination_7)
                y-=5 
                c.line(50, y, 50 + 555, y)
                y -= 17
                
            else:
                      
                c.drawString(180, y, abdominal_examination_7)
                c.drawString(350, y, Scars_7_2 +" "+ row['7.2Scars'])
                c.drawString(420, y, Skin_abnormalities +" "+ row['7.3Skin abnormalities (abdominal wall veins, hemangiomas)'])
            #horizontal line
                y-=5
                c.line(50, y, 50 + 555, y)
                y -= 17  # Move down for the next line
                c.drawString(50, y, Protrusions + " "+row['7.4Protrusions (hernia, diastasis reti)'])
                c.drawString(180, y, tenderness_7 +" "+ row['7.1Tenderness'])
                c.drawString(300, y, Guarding  +" "+ row['7.2Guarding'])
                c.drawString(400, y, Hepatomegaly  +" "+ row['7.3Hepatomegaly'])
            #horizontal line
                y-=5
                c.line(50, y, 50 + 555, y)
                y -= 17  # Move down for the next line
                c.drawString(50, y, Splenomegaly  +" "+ row['7.4Splenomegaly'])
                c.drawString(150, y, Enlarged_kidneys  + row['7.5Enlarged kidneys'])
                c.drawString(270, y, Ascites  + row['7.2(d)Ascites'])
                c.drawString(370, y, Bowel_Sounds  + row['7.1(e)Bowel Sounds'])
            
        
            #horizontal line
                y-=5
                c.line(50, y, 50 + 500, y)
                y -= 17  # Move down for the next line
#             c.drawString(50, y, peripheral_pulses_felt  + row['6.1(f)Peripheral pulses felt (Radial, brachial rate, rhythm, volume, contour)'])
#             c.drawString(400, y, apex_position_6_1_g + row['6.1(g)Apex: Position'])
#             y-=5
#             c.line(50, y, 50 + 500, y)
#             y -= 17
#             c.drawString(50, y, if_apex_abnormal_specify_6_1_g + row['6.1(g)if Apex, Abnormal specify'])
#             c.drawString(270, y, Murmurs_6_3_h + row['6.3(h)Murmurs'])
#             c.drawString(400, y, If_yes_specify_6_4_h + row['6.4(h) If yes, specify'])
#             #horizontal line
#             y-=5
#             c.line(50, y, 50 + 500, y)
#             y -= 17  # Move down for the next line
#             #new line add here c.drawString(50, y, ifApex_Abnormal_specify_6_1_g  + row['6.1(g)if Apex, Abnormal specify'])
#             y-=5
#             c.line(50, y, 50 + 500, y)
#             y -= 17
#             #new line add herec.drawString(50, y, Murmurs_6_3_h + row['6.3(h)Murmurs'])
#             #horizontal line
#             y-=5
#             c.line(50, y, 50 + 500, y)
#             y -= 17  # Move down for the next line
#             # new line add herec.drawString(50, y, If_yes_specify_6_4_h  + row['6.4(h) If yes, specify'])
#             y-=5 
#             c.line(50, y, 50 + 500, y)
#             y -= 17
#             # new line add herec.drawString(50, y, added_sounds_6_3_d + row['6.3(d)Added sounds'])



             #Neurological Examination
    
            c.setFillColor("black")  # Set text color back to black
            c.setFont("Helvetica-Bold", 10)
            c.drawString(50, y, neurological_examination)  #sub heading Cardiovascular Examination
            
#             c.setFont("Helvetica", 9)
#             c.drawString(195, y, cardiovascular_examination_6_2 + row["6.2Cardiovascular Examination"])
#             c.drawString(410, y, precordial_bulge_6_2_e + row['6.2(e)Precordial bulge'])
            #horizontal line
            y-=5
            c.line(50, y, 50 + 555, y)
            y -= 17  # Move down for the next line
#             c.drawString(50, y, pectus_carinatum_excavatum_6_3_e + row['6.3(e)Pectus carinatum / excavatum'])
#             c.drawString(250, y, scars_6_4_e  + row['6.4(e)Scars'])
#             c.drawString(350, y, visible_cardiac_impulse_6_5_e  + row['6.5(e)Visible cardiac impulse'])
            #horizontal line
#             y-=5
#             c.line(50, y, 50 + 500, y)
#             y -= 17  # Move down for the next line
#             c.drawString(50, y, increased_WOB_tachypnea_6_6_e  + row['6.6(e)Increased WOB-tachypnea, intercostals indrawing, tracheal tug, head bobbing, nasal flaring'])
        
            #horizontal line
#             y-=5
#             c.line(50, y, 50 + 500, y)
#             y -= 17  # Move down for the next line
#             c.drawString(50, y, peripheral_pulses_felt  + row['6.1(f)Peripheral pulses felt (Radial, brachial rate, rhythm, volume, contour)'])
#             c.drawString(400, y, apex_position_6_1_g + row['6.1(g)Apex: Position'])
#             y-=5
#             c.line(50, y, 50 + 500, y)
#             y -= 17
#             c.drawString(50, y, if_apex_abnormal_specify_6_1_g + row['6.1(g)if Apex, Abnormal specify'])
#             c.drawString(270, y, Murmurs_6_3_h + row['6.3(h)Murmurs'])
#             c.drawString(400, y, If_yes_specify_6_4_h + row['6.4(h) If yes, specify'])
#             #horizontal line
#             y-=5
#             c.line(50, y, 50 + 500, y)
#             y -= 17  # Move down for the next line
#             #new line add here c.drawString(50, y, ifApex_Abnormal_specify_6_1_g  + row['6.1(g)if Apex, Abnormal specify'])
#             y-=5
#             c.line(50, y, 50 + 500, y)
#             y -= 17
#             #new line add herec.drawString(50, y, Murmurs_6_3_h + row['6.3(h)Murmurs'])
#             #horizontal line
#             y-=5
#             c.line(50, y, 50 + 500, y)
#             y -= 17  # Move down for the next line
#             # new line add herec.drawString(50, y, If_yes_specify_6_4_h  + row['6.4(h) If yes, specify'])
#             y-=5 
#             c.line(50, y, 50 + 500, y)
#             y -= 17
#             # new line add herec.drawString(50, y, added_sounds_6_3_d + row['6.3(d)Added sounds'])

        
            
        
        
        #Gait Examination
        
            y-=5
            c.line(50, y, 50 + 555, y)
            y -= 17
            
            c.setFillColor("black")  # Set text color back to black
            c.setFont("Helvetica-Bold", 10)
            c.drawString(50, y, gait_examination)  #sub heading Cardiovascular Examination
            
            c.setFont("Helvetica", 9)
            Gait = row ["8Gait"].strip()
            if Gait == "Normal":
                c.setFont("Helvetica", 9)
                c.drawString(200, y, Gait)
                y-=5 
                c.line(50, y, 50 + 555, y)
                y -= 17
                
            else:
                c.drawString(150, y, Gait + row["8Gait"])
                c.drawString(230, y, Antalgic_gait +" "+ row["8.1Antalgic gait?(Reduced time spent weight-bearing on the affected side. Spectrum of possible causes (e.g., trauma to sole of foot, spinal osteomyelitis)"])
                c.drawString(320, y, Circumduction_gait +" "+ row["8.2Circumduction gait?(Excessive hip abduction as the leg swings forwards)"])
                c.drawString(430, y, Spastic_gait +" "+ row["8.3Spastic gait?(Stiff, foot-dragging with foot inversion)"])
            #horizontal line
                y-=5
                c.line(50, y, 50 + 555, y)
                y -= 17  # Move down for the next line
                c.drawString(50, y, Ataxic_gait  +" "+ row["8.4Ataxic gait?(Instability with an alternating narrow to wide base of gait. Seen in ataxic cerebral palsy affecting the cerebellum, cerebellar ataxia, and Friedreich's ataxia)"])
                c.drawString(120, y, Trendelenburg  +" "+ row["8.5Trendelenburg's gait?(Results from hip abductor muscle weakness)"])
                c.drawString(240, y, Toe_walking  + row["8.6Toe-walking gait with absent heel contact?(Diplegic cerebral palsy presentation of mild lysosomal storage disorder.)"])
                c.drawString(460, y, Stepping_gait  + row["8.7Stepping gait?(Spina bifida, polio)"])
                y-=5
                c.line(50, y, 50 + 555, y)
                y -= 17 
                c.drawString(50, y, Clumsy_gait  +" "+ row["8.8Clumsy gait?(Frequent falls, and with difficulty in self-help skills such as dressing or feeding at school. Poor handwriting and learning disabilities may be noted)"])
                c.drawString(130, y, Central_nervous  +" "+ row["8.9Central nervous system Examination"])
                c.drawString(360, y, Hypertrophy  + row["8.9Hypertrophy"])
                c.drawString(460, y, Seizure_activity  + row["8.10Seizure activity"])
            #horizontal line
                y-=5
                c.line(50, y, 50 + 555, y)
                y -= 17  # Move down for the next line
                c.drawString(50, y, Wasting +" "+ row["8.11Wasting"])
                c.drawString(120, y, Chorea  +" "+ row["8.12Chorea"])
                c.drawString(200, y, Fasciculation +" "+ row["8.13Fasciculation"])
                c.drawString(260, y, Tremor  +" "+ row["8.14Tremor (postural, intention, resting, etc.)"])
                c.drawString(330, y, Athetosis  + row["8.15Athetosis"])
                c.drawString(430, y, Dystonia  + row["8.16Dystonia"])
                y-=5
                c.line(50, y, 50 + 555, y)
                y -= 17 
                c.drawString(50, y, Others +" "+ row["8.17Others (Specify)"])
                c.drawString(150, y, Muscular_Power  + row["8.1Muscular Power"])
                c.drawString(270, y, Muscle_tone + row["8.2Muscle tone"])
                c.drawString(390, y, Deep_Tendons  + row["8.3Deep Tendons Reflexes"])
                y-=5
                c.line(50, y, 50 + 555, y)
                y -= 17 
        
            #horizontal line
            y -= 12  # Move down for the next line
#             y -= 7 # gap for next section
            c.drawString(550, y+460, page_1 )




 # Iterate over each record in the CSV file
            if heading_text == "Child Health Status Report":# Check if a new report begins
                c.showPage()  # Start a new page
                y = 750  # Reset y-coordinate for new page
                # Redraw heading and survey text on the new page
                c.setFont("Helvetica-Bold", 12)
                text_width = c.stringWidth(heading_text, "Helvetica-Bold")
                x = (letter[0] - text_width) / 2
                c.drawString(x, y, heading_text)
                y -= 30  # Move down for the next line
                c.setFont("Helvetica", 12)
                text_width = c.stringWidth(survey_text, "Helvetica")
                x = (letter[0] - text_width) / 2
                c.drawString(x, y, survey_text)
                y -= 30  # Move down for the next line
            
            
             #Physician Section
#             c.setFillColor(pink)  # Set fill color to pink
            c.setFillColorRGB(pink_rgb[0]/255, pink_rgb[1]/255, pink_rgb[2]/255)  # Set fill color to pink using RGB values
            c.setStrokeColor(black)  # Set stroke color to pink
            c.rect(49, y, 555, 21, fill=1)  # Draw a filled rectangle as background
            c.setFont("Helvetica-Bold", 10)
            c.setFillColor("black")  # Set text color to black 
            c.drawString(50, y+5, physician_section_text)
            y += 20
            
            c.setFillColor("black")  # Set text color back to black
            y -= 32  # Move down for the next line
            c.setFont("Helvetica-Bold", 9)
            c.drawString(50, y, referred_to_pediatric_clinic)  #sub Referred to pediatric clinic?
            c.setFont("Helvetica", 9)
            c.drawString(175, y, "" + row['12.Referred to pediatric clinic?'])
            c.setFont("Helvetica-Bold", 9)
            c.drawString(210, y, test_required)  #sub Referred to pediatric clinic?
            c.setFont("Helvetica", 9)
            c.drawString(280, y, "" + row['12.Test required?'])
            
            y-=5
            c.line(50, y, 50 + 555, y)
            y -= 10 
            c.setFont("Helvetica-Bold", 9)
            c.drawString(50, y, diagnosis_text)  #sub Referred to pediatric clinic?
            c.setFont("Helvetica", 9)
            c.drawString(110, y, "" + row['12.Diagnosis'])
            y-=5
            c.line(50, y, 50 + 555, y)
            y -= 1 
            c.setFillColor("black")  # Set text color back to black
            y -= 10  # Move down for the next line
            
            c.setFont("Helvetica-Bold", 9)
            c.drawString(50, y, medicine_prescribe)  #sub Referred to pediatric clinic?
            c.setFont("Helvetica", 9)
            c.drawString(135, y, "" + row['12.Medicine Prescribe'])
            y-=5
            c.line(50, y, 50 + 555, y)
            y -= 1 
            
            c.setFillColor("black")  # Set text color back to black
            y -= 10  # Move down for the next line
            c.setFont("Helvetica-Bold", 9)
            c.drawString(50, y, doctors_name_speciality)  #sub Referred to pediatric clinic?
            c.setFont("Helvetica", 9)
            c.drawString(195, y, "" + row['12.Name of Doctors and Speciality?'])
            
            
            y-=5
            c.line(50, y, 50 + 555, y)
            y -= 17
            y -= 3 # gap
        
        
        #3.1 section child_vaccinated
        
            #horizontal line
            y -= 10  # Move down for the next line
            c.setFillColorRGB(pink_rgb[0]/255, pink_rgb[1]/255, pink_rgb[2]/255)  # Set fill color to pink using RGB values
            c.setStrokeColor(black)  # Set stroke color to pink
            c.rect(49, y, 555, 21, fill=1)  # Draw a filled rectangle as background
            c.setFont("Helvetica-Bold", 10)
            c.setFillColor("black")  # Set text color to black 
            c.drawString(50, y+5, child_vaccinated_text)
            y += 20
            
            c.setFillColor("black")  # Set text color back to black
            y -= 32  # Move down for the next line
            c.setFont("Helvetica-Bold", 9)
            c.drawString(50, y, child_vaccinated)  
            c.setFont("Helvetica", 9)
            c.drawString(135, y, "" + row['3.1Child vaccinated?'])
            c.setFont("Helvetica-Bold", 9)
            c.drawString(220, y, aBCG)  
            c.setFont("Helvetica", 9)
            c.drawString(245, y, "" + row['3.1(a)BCG'])
            c.setFont("Helvetica-Bold", 9)
            c.drawString(300, y, bOPV)  
            c.setFont("Helvetica", 9)
            c.drawString(325, y, "" + row['3.1(b)OPV'])
            c.setFont("Helvetica-Bold", 9)
            c.drawString(375, y, cPenta)  
            c.setFont("Helvetica", 9)
            c.drawString(410, y, "" + row['3.1(c)Penta'])
            c.setFont("Helvetica-Bold", 9)
            c.drawString(470, y, dPCV)  
            c.setFont("Helvetica", 9)
            c.drawString(500, y, "" + row['3.1(d) PCV'])
            
            y-=5
            c.line(50, y, 50 + 555, y)
            y -= 1 
            
            c.setFillColor("black")  # Set text color back to black
            y -= 10  # Move down for the next line
            c.setFont("Helvetica-Bold", 9)
            c.drawString(50, y, eMeasles) 
            c.setFont("Helvetica", 9)
            c.drawString(97, y, "" + row['3.1(e)Measles'])
            c.setFont("Helvetica-Bold", 9)
            c.drawString(155, y, fChicken_Pox)  
            c.setFont("Helvetica", 9)
            c.drawString(218, y, "" + row['3.1(f)Chicken Pox'])
            c.setFont("Helvetica-Bold", 9)
            c.drawString(270, y, gTyphoid)  
            c.setFont("Helvetica", 9)
            c.drawString(310, y, "" + row['3.1(g)Typhoid'])
            c.setFont("Helvetica-Bold", 9)
            c.drawString(370, y, hCOVID)  
            c.setFont("Helvetica", 9)
            c.drawString(420, y, "" + row['3.1(h)COVID-19'])
            y-=5
            c.line(50, y, 50 + 555, y)
            y -= 1 
            
            c.setFillColor("black")  # Set text color back to black
            y -= 10  # Move down for the next line
            c.setFont("Helvetica-Bold", 9)
            c.drawString(50, y, iothers)  #sub Referred to pediatric clinic?
            c.setFont("Helvetica", 9)
            c.drawString(195, y, "" + row["3.1(i)If any others mention name"])
            y-=5
            c.line(50, y, 50 + 555, y)
            y -= 22 
            y-=5
            c.line(50, y, 50 + 555, y)
            
            
            #section 11 life style
            c.setFillColorRGB(pink_rgb[0]/255, pink_rgb[1]/255, pink_rgb[2]/255)  # Set fill color to pink using RGB values
            c.setStrokeColor(black)  # Set stroke color to pink
            c.rect(49, y, 555, 21, fill=1)  # Draw a filled rectangle as background
            c.setFont("Helvetica-Bold", 10)
            c.setFillColor("black")  # Set text color to black 
            c.drawString(50, y+5, life_style)
            y += 20
            
            c.setFillColor("black")  # Set text color back to black
            y -= 32  # Move down for the next line
            c.setFont("Helvetica-Bold", 9)
            c.drawString(50, y, food)  
            c.setFont("Helvetica", 9)
            c.drawString(77, y, "" + row['11(a)Do you know the difference between junk and healthy food'])
            c.setFont("Helvetica-Bold", 9)
            c.drawString(100, y, diet)  
            c.setFont("Helvetica", 9)
            c.drawString(125, y, "" + row['11(b)What does your diet mainly consist of'])
            c.setFont("Helvetica-Bold", 9)
            c.drawString(187, y, sport)  
            c.setFont("Helvetica", 9)
            c.drawString(220, y, "" + row["11(c)Do you participate in physical activities/ Sports (choice=Never)"])
            c.setFont("Helvetica-Bold", 9)
            c.drawString(275, y, at_school)  
            c.setFont("Helvetica", 9)
            c.drawString(320, y, "" + row["11(d)Do you participate in physical activities/ Sports (choice=At school)"])
            c.setFont("Helvetica-Bold", 9)
            c.drawString(375, y, out_school)  
            c.setFont("Helvetica", 9)
            c.drawString(450, y, "" + row["11(e)Do you participate in physical activities/ Sports (choice=outside school)"])
            c.setFont("Helvetica-Bold", 9)
            c.drawString(505, y, s_well)  
            c.setFont("Helvetica", 9)
            c.drawString(555, y, "" + row["(h)Are you able to sleep well?"])
            y-=5
            c.line(50, y, 50 + 555, y)
            y -= 10 
            c.setFont("Helvetica-Bold", 9)
            c.drawString(50, y, tv)  
            c.setFont("Helvetica", 9)
            c.drawString(115, y, "" + row['11(f)How much time do you spend on screen (Mobile, Computer, Tv) for entertainment purpose?'])
            c.setFont("Helvetica-Bold", 9)
            c.drawString(187, y, s_media)  
            c.setFont("Helvetica", 9)
            c.drawString(250, y, "" + row['11(g)How much time do you spend on Social Media? (Facebook, Twitter, Instagram)'])
            c.setFont("Helvetica-Bold", 9)
            c.drawString(375, y, s_night)  
            c.setFont("Helvetica", 9)
            c.drawString(450, y, "" + row["(g)How much time do you spend sleeping at Night?"])
            y-=5
            c.line(50, y, 50 + 555, y)
            y -= 10 
            c.setFont("Helvetica-Bold", 9)
            c.drawString(50,y,grow_up)
            c.setFont("Helvetica", 9)
            c.drawString(155, y, "" + row["(i)What do you want to be when you grow up?"])
            y-=5
            c.line(50, y, 50 + 555, y)
            c.drawString(550, y+290, page_2 )

            
            
            
            
            

            

        # Save the canvas as a PDF file
        c.showPage() #show page next by next
        c.save()
        

        print(f"PDF report generated successfully: {output_filename}")

# %%
if __name__ == "__main__":
    # Specify the input CSV filename and the output PDF filename
    input_filename = "newrep.csv"
    output_filename = "all_text.pdf"

    # Generate the child health report PDF
    generate_child_health_report(input_filename, output_filename)
# Out:
# PDF report generated successfully: all_text.pdf
